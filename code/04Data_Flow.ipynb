# %% [markdown]
# # 📊 CRM 리드 상태 및 단계 분석

# %% [markdown]
# ## ✅ 2. 리드의 상태 및 단계
#
# | 열 이름                          | 설명                                          |
# | ----------------------------- | ------------------------------------------- |
# | `Status_Text`                 | 리드 상태 (예: Active, Converted, Closed 등)      |
# | `Reason_Code_Text`            | 해당 상태가 된 이유 (예: quote sent, budget issue 등) |
# | `Lead_Life_Cycle_Status_Code` | 리드 생애주기 상태 코드                               |
# | `Main_Contact_Person_Status`  | 연락처 상태                                      |
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %%
# 데이터 불러오기
df = pd.read_csv('../data/leads_df_cleaned.csv')

# 주요 상태 관련 열만 추출
status_cols = ['Status_Text',  'Lead_Life_Cycle_Status_Code', 'Main_Contact_Person_Status']
df_status = df[status_cols]
df_status.head()
# Out:
# C:\Users\ha\AppData\Local\Temp\ipykernel_10368\704369770.py:2: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/leads_df_cleaned.csv')
#    Status_Text  Lead_Life_Cycle_Status_Code  Main_Contact_Person_Status
# 0       Closed                          5.0                         2.0
# 1    Converted                          6.0                         2.0
# 2       Closed                          5.0                         1.0
# 3       Closed                          5.0                         2.0
# 4  Unqualified                          2.0                         1.0

# %%
df_status.isnull().sum()


# 한글 폰트 설정 (예: 맑은 고딕)
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %% [markdown]
# ## 📈 리드 상태별 분포

# %%
sns.countplot(data=df_status, x='Status_Text')
plt.title('리드 상태 분포')
plt.xlabel('Status_Text')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 📈 Lead_Life_Cycle_Status_Code 분포

# %%
sns.countplot(data=df_status, x='Lead_Life_Cycle_Status_Code')
plt.title('생애주기 상태 코드 분포')
plt.xlabel('코드')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## 📈 Main_Contact_Person_Status 분포_male or female

# %%
sns.countplot(data=df_status, x='Main_Contact_Person_Status')
plt.title('담당자 상태 분포')
plt.xlabel('상태 코드')
plt.ylabel('Count')
plt.show()

# %%
# 📈 담당자 성별 분포
df_status = df_status[df_status['Main_Contact_Person_Status'] != 4]
sns.countplot(data=df_status, x='Main_Contact_Person_Status')
plt.title('담당자 상태 분포')
plt.xlabel('상태 코드')
plt.ylabel('Count')
plt.show()
